# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
print(len(dict_flux))
# Out:
# 430

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0c.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0c.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0d.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0d.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0e.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0e.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0f.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0f.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0g.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0g.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0h.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0h.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
len(dict_flux)
# Out:
# 469

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go1.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go1.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go1b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go1b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go2.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go2.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go2b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go2b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go3.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go3.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go3b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go3b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go4.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go4.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go4b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go4b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go5.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go5.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go5b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go5b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go6.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go6.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go6b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go6b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go7.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go7.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go7b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go7b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go8.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go8.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go8b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go8b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go9b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go9b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go10b.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go10b.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go1add1.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go1add1.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
len(dict_flux)
# Out:
# 435

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go1add2.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go1add2.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go2add1.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go2add1.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go2add2.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go2add2.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go3badd1.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go3badd1.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go3badd2.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go3badd2.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go4badd1.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go4badd1.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_go4badd2.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_go4badd2.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()

# %%
from openpyxl import load_workbook
import pickle

wb = load_workbook(filename = 'Flux_g0i.xlsx')
ws = wb['Sheet1']

# list of reaction abbreviations
rxn_abbr = ws['A']
rxn_abbr = [x.value for x in rxn_abbr]
rxn_abbr = rxn_abbr[1:]

# fluxes
rxn_flux = ws['C']
rxn_flux = rxn_flux[1:]
rxn_flux = [float(x.value) for x in rxn_flux]

dict_flux = {}
for i in range(len(rxn_abbr)):
	if (abs(rxn_flux[i]) >= 1e-5) and ('BIOMASS' not in rxn_abbr[i]):
		dict_flux[rxn_abbr[i]]=rxn_flux[i]

# save as pickle
file = open(r'dict_flux_g0i.pkl', 'wb')
pickle.dump(dict_flux, file)
file.close()
