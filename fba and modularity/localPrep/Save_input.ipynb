# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

# %%
dict_flux['EX_zn2_e']
# Out:
# -0.0002990560501195959

# %%
dict_all['EX_zn2_e']
# Out:
# {('zn2_e', 'EX_zn2_e'): 1.0}

# %%
lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)

# %%
edges[('EX_zn2_e', 'zn2_e')]
# Out:
# 0.0002990560501195959

# %%
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))
# Out:
# 430
# 432
# 1830

# %%
# save to python 2 format with protocol=2
file = open('../g0/lst_reactions_g0.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0/lst_metabolites_g0.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0/edges_g0.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0/lst_reactions_g0.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0/lst_metabolites_g0.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0/edges_g0.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 430
# 432
# 1830

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0b/lst_reactions_g0b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0b/lst_metabolites_g0b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0b/edges_g0b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 434
# 437
# 1844

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0c.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0c/lst_reactions_g0c.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0c/lst_metabolites_g0c.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0c/edges_g0c.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 431
# 433
# 1832

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0d.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0d/lst_reactions_g0d.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0d/lst_metabolites_g0d.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0d/edges_g0d.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 434
# 436
# 1842

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0e.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0e/lst_reactions_g0e.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0e/lst_metabolites_g0e.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0e/edges_g0e.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 448
# 450
# 1909

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0f.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0f/lst_reactions_g0f.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0f/lst_metabolites_g0f.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0f/edges_g0f.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 455
# 455
# 1921

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0g.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0g/lst_reactions_g0g.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0g/lst_metabolites_g0g.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0g/edges_g0g.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 465
# 461
# 1952

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0h.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0h/lst_reactions_g0h.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0h/lst_metabolites_g0h.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0h/edges_g0h.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 469
# 467
# 1964

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go1.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go1/lst_reactions_go1.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go1/lst_metabolites_go1.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go1/edges_go1.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 431
# 432
# 1825

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go1b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go1b/lst_reactions_go1b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go1b/lst_metabolites_go1b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go1b/edges_go1b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 438
# 439
# 1842

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go2.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go2/lst_reactions_go2.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go2/lst_metabolites_go2.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go2/edges_go2.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 427
# 430
# 1811

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go2b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go2b/lst_reactions_go2b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go2b/lst_metabolites_go2b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go2b/edges_go2b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 437
# 438
# 1835

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go3.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go3/lst_reactions_go3.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go3/lst_metabolites_go3.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go3/edges_go3.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 435
# 436
# 1830

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go3b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go3b/lst_reactions_go3b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go3b/lst_metabolites_go3b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go3b/edges_go3b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 433
# 434
# 1821

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go4.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go4/lst_reactions_go4.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go4/lst_metabolites_go4.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go4/edges_go4.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 435
# 436
# 1830

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go4b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go4b/lst_reactions_go4b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go4b/lst_metabolites_go4b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go4b/edges_go4b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 427
# 429
# 1797

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go5.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go5/lst_reactions_go5.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go5/lst_metabolites_go5.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go5/edges_go5.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 433
# 435
# 1822

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go5b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go5b/lst_reactions_go5b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go5b/lst_metabolites_go5b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go5b/edges_go5b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 437
# 438
# 1832

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go6.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go6/lst_reactions_go6.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go6/lst_metabolites_go6.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go6/edges_go6.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 433
# 435
# 1820

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go6b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go6b/lst_reactions_go6b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go6b/lst_metabolites_go6b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go6b/edges_go6b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 436
# 438
# 1827

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go7.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go7/lst_reactions_go7.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go7/lst_metabolites_go7.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go7/edges_go7.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 432
# 433
# 1816

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go7b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go7b/lst_reactions_go7b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go7b/lst_metabolites_go7b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go7b/edges_go7b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 436
# 436
# 1828

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go8.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go8/lst_reactions_go8.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go8/lst_metabolites_go8.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go8/edges_go8.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 432
# 433
# 1816

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go8b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go8b/lst_reactions_go8b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go8b/lst_metabolites_go8b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go8b/edges_go8b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 437
# 439
# 1829

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go9b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go9b/lst_reactions_go9b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go9b/lst_metabolites_go9b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go9b/edges_go9b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 436
# 437
# 1825

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go10b.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go10b/lst_reactions_go10b.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go10b/lst_metabolites_go10b.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go10b/edges_go10b.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 434
# 434
# 1824

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go1add1.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go1add1/lst_reactions_go1add1.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go1add1/lst_metabolites_go1add1.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go1add1/edges_go1add1.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 435
# 436
# 1832

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go1add2.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go1add2/lst_reactions_go1add2.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go1add2/lst_metabolites_go1add2.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go1add2/edges_go1add2.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 427
# 430
# 1811

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go2add1.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go2add1/lst_reactions_go2add1.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go2add1/lst_metabolites_go2add1.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go2add1/edges_go2add1.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 428
# 430
# 1814

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go2add2.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go2add2/lst_reactions_go2add2.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go2add2/lst_metabolites_go2add2.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go2add2/edges_go2add2.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 428
# 430
# 1804

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go3badd1.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go3badd1/lst_reactions_go3badd1.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go3badd1/lst_metabolites_go3badd1.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go3badd1/edges_go3badd1.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 433
# 434
# 1822

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go3badd2.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go3badd2/lst_reactions_go3badd2.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go3badd2/lst_metabolites_go3badd2.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go3badd2/edges_go3badd2.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 428
# 431
# 1801

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go4badd1.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go4badd1/lst_reactions_go4badd1.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go4badd1/lst_metabolites_go4badd1.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go4badd1/edges_go4badd1.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 427
# 429
# 1797

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_go4badd2.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../go4badd2/lst_reactions_go4badd2.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../go4badd2/lst_metabolites_go4badd2.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../go4badd2/edges_go4badd2.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 431
# 433
# 1807

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0i.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0i/lst_reactions_g0i.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0i/lst_metabolites_g0i.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0i/edges_g0i.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 434
# 436
# 1842

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0j.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0j/lst_reactions_g0j.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0j/lst_metabolites_g0j.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0j/edges_g0j.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 431
# 434
# 1836

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0k.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0k/lst_reactions_g0k.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0k/lst_metabolites_g0k.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0k/edges_g0k.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 434
# 437
# 1844

# %%
import pickle

file1 = open('dict_all.pkl', 'rb')
dict_all = pickle.load(file1)
file1.close()

file2 = open('dict_flux_g0l.pkl', 'rb')
dict_flux = pickle.load(file2)
file2.close()

lst_reactions = []
lst_metabolites = []
edges = {}
for _reac, _flux in dict_flux.items():
	lst_reactions.append(_reac)
	dict_this_reaction = dict_all[_reac]
	if _flux > 0:
		for _pairs, _stoi in dict_this_reaction.items():
			edges[_pairs] = _flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
	else:
		for _pairs, _stoi in dict_this_reaction.items():
			new_pairs = (_pairs[1], _pairs[0])
			edges[new_pairs] = -_flux * _stoi
			for node in _pairs:
				if (node != _reac) and (node not in lst_metabolites):
					lst_metabolites.append(node)
                    
print(len(lst_reactions))
print(len(lst_metabolites))
print(len(edges))

# save to python 2 format with protocol=2
file = open('../g0l/lst_reactions_g0l.pkl', 'wb')
pickle.dump(lst_reactions, file, protocol=2)
file.close()

file = open('../g0l/lst_metabolites_g0l.pkl', 'wb')
pickle.dump(lst_metabolites, file, protocol=2)
file.close()

file = open('../g0l/edges_g0l.pkl', 'wb')
pickle.dump(edges, file, protocol=2)
file.close()
# Out:
# 434
# 436
# 1842
